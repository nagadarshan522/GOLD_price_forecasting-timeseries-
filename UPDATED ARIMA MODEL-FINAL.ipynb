# %%
# Import libraries
from pandas import read_csv
from matplotlib import pyplot
from numpy import sqrt
import warnings
warnings.filterwarnings('ignore')
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
series = read_csv("C:\\Users\\Lenovo\\Downloads\\Gold_data.csv", header=0, index_col=0, parse_dates=True)

# %%
series.head()
# Out:
#               price
# date
# 2016-01-01  2252.60
# 2016-01-02  2454.50
# 2016-01-03  2708.10
# 2016-01-04  2577.80
# 2016-01-05  2597.75

# %%
# Resetting index 
series1 = series.reset_index()
series1.head()
# Out:
#         date    price
# 0 2016-01-01  2252.60
# 1 2016-01-02  2454.50
# 2 2016-01-03  2708.10
# 3 2016-01-04  2577.80
# 4 2016-01-05  2597.75

# %%
# line plot of time series
from pandas import read_csv
from matplotlib import pyplot
series.plot()
pyplot.show()

# %%
# separate out a validation dataset (90%-training data and 10% test data)
split_point = len(series) - 218
dataset, validation = series[0:split_point], series[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('dataset.csv', header=False)
validation.to_csv('validation.csv', header=False)
# Out:
# Dataset 1964, Validation 218

# %% [markdown]
# Persistence/ Base model

# %%
# evaluate a persistence model
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from math import sqrt
# load data
train = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)
# prepare data
X = train.values
X = X.astype('float32')
train_size = int(len(X) * 0.80)
train, test = X[0:train_size], X[train_size:]

# %%
X
# Out:
# array([2252.6, 2454.5, 2708.1, ..., 4336.7, 4336.7, 4387.9], dtype=float32)

# %%
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    yhat = history[-1]
    predictions.append(yhat)
# observation
    obs = test[i]
    history.append(obs)
    print('>Predicted=%.1f, Observed =%.3f' % (yhat, obs))
# report performance
rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# Out:
# >Predicted=4135.6, Observed =4175.300
# >Predicted=4175.3, Observed =4160.100
# >Predicted=4160.1, Observed =4211.300
# >Predicted=4211.3, Observed =4229.700
# >Predicted=4229.7, Observed =4237.000
# >Predicted=4237.0, Observed =4230.500
# >Predicted=4230.5, Observed =4229.400
# >Predicted=4229.4, Observed =4193.500
# >Predicted=4193.5, Observed =4175.600
# >Predicted=4175.6, Observed =4146.500
# >Predicted=4146.5, Observed =4082.600
# >Predicted=4082.6, Observed =3573.500
# >Predicted=3573.5, Observed =3559.000
# >Predicted=3559.0, Observed =3962.800
# >Predicted=3962.8, Observed =3974.000
# >Predicted=3974.0, Observed =4154.100
# >Predicted=4154.1, Observed =4080.300
# >Predicted=4080.3, Observed =4254.400
# >Predicted=4254.4, Observed =4895.800
# >Predicted=4895.8, Observed =4544.800
# >Predicted=4544.8, Observed =4485.700
# >Predicted=4485.7, Observed =4631.000
# >Predicted=4631.0, Observed =4353.600
# >Predicted=4353.6, Observed =4153.400
# >Predicted=4153.4, Observed =4190.800
# >Predicted=4190.8, Observed =4244.300
# >Predicted=4244.3, Observed =4248.900
# >Predicted=4248.9, Observed =4248.900
# >Predicted=4248.9, Observed =4207.700
# >Predicted=4207.7, Observed =4244.300
# >Predicted=4244.3, Observed =4244.000
# >Predicted=4244.0, Observed =4189.200
# >Predicted=4189.2, Observed =4233.100
# >Predicted=4233.1, Observed =4235.400
# >Predicted=4235.4, Observed =4235.400
# >Predicted=4235.4, Observed =4211.300
# >Predicted=4211.3, Observed =4153.100
# >Predicted=4153.1, Observed =4172.600
# >Predicted=4172.6, Observed =4175.800
# >Predicted=4175.8, Observed =4194.800
# >Predicted=4194.8, Observed =4198.000
# >Predicted=4198.0, Observed =4198.000
# >Predicted=4198.0, Observed =3606.900
# >Predicted=3606.9, Observed =3582.500
# >Predicted=3582.5, Observed =4018.700
# >Predicted=4018.7, Observed =4063.100
# >Predicted=4063.1, Observed =4126.200
# >Predicted=4126.2, Observed =4086.500
# >Predicted=4086.5, Observed =4278.500
# >Predicted=4278.5, Observed =4966.300
# >Predicted=4966.3, Observed =4544.800
# >Predicted=4544.8, Observed =4456.800
# >Predicted=4456.8, Observed =4636.900
# >Predicted=4636.9, Observed =4353.600
# >Predicted=4353.6, Observed =4222.900
# >Predicted=4222.9, Observed =4222.900
# >Predicted=4222.9, Observed =4205.300
# >Predicted=4205.3, Observed =4233.900
# >Predicted=4233.9, Observed =4232.400
# >Predicted=4232.4, Observed =4229.500
# >Predicted=4229.5, Observed =4267.700
# >Predicted=4267.7, Observed =4263.400
# >Predicted=4263.4, Observed =4263.400
# >Predicted=4263.4, Observed =4273.200
# >Predicted=4273.2, Observed =4302.300
# >Predicted=4302.3, Observed =4294.900
# >Predicted=4294.9, Observed =4275.300
# >Predicted=4275.3, Observed =4298.700
# >Predicted=4298.7, Observed =4297.500
# >Predicted=4297.5, Observed =4297.500
# >Predicted=4297.5, Observed =4294.900
# >Predicted=4294.9, Observed =4320.000
# >Predicted=4320.0, Observed =3625.400
# >Predicted=3625.4, Observed =3607.700
# >Predicted=3607.7, Observed =3977.100
# >Predicted=3977.1, Observed =4015.800
# >Predicted=4015.8, Observed =4176.900
# >Predicted=4176.9, Observed =4086.500
# >Predicted=4086.5, Observed =4320.200
# >Predicted=4320.2, Observed =4892.100
# >Predicted=4892.1, Observed =4547.100
# >Predicted=4547.1, Observed =4443.800
# >Predicted=4443.8, Observed =4636.100
# >Predicted=4636.1, Observed =4403.200
# >Predicted=4403.2, Observed =4349.900
# >Predicted=4349.9, Observed =4376.600
# >Predicted=4376.6, Observed =4370.000
# >Predicted=4370.0, Observed =4335.400
# >Predicted=4335.4, Observed =4355.800
# >Predicted=4355.8, Observed =4352.300
# >Predicted=4352.3, Observed =4352.300
# >Predicted=4352.3, Observed =4362.200
# >Predicted=4362.2, Observed =4403.800
# >Predicted=4403.8, Observed =4475.200
# >Predicted=4475.2, Observed =4533.900
# >Predicted=4533.9, Observed =4564.100
# >Predicted=4564.1, Observed =4561.900
# >Predicted=4561.9, Observed =4561.900
# >Predicted=4561.9, Observed =4651.800
# >Predicted=4651.8, Observed =4696.500
# >Predicted=4696.5, Observed =4727.900
# >Predicted=4727.9, Observed =4693.700
# >Predicted=4693.7, Observed =4751.700
# >Predicted=4751.7, Observed =3564.600
# >Predicted=3564.6, Observed =3605.000
# >Predicted=3605.0, Observed =3977.100
# >Predicted=3977.1, Observed =4011.800
# >Predicted=4011.8, Observed =4134.100
# >Predicted=4134.1, Observed =4112.000
# >Predicted=4112.0, Observed =4351.700
# >Predicted=4351.7, Observed =4894.100
# >Predicted=4894.1, Observed =4571.200
# >Predicted=4571.2, Observed =4455.900
# >Predicted=4455.9, Observed =4636.100
# >Predicted=4636.1, Observed =4427.900
# >Predicted=4427.9, Observed =4692.700
# >Predicted=4692.7, Observed =4668.100
# >Predicted=4668.1, Observed =4672.600
# >Predicted=4672.6, Observed =4672.600
# >Predicted=4672.6, Observed =4763.900
# >Predicted=4763.9, Observed =4793.000
# >Predicted=4793.0, Observed =4667.900
# >Predicted=4667.9, Observed =4700.900
# >Predicted=4700.9, Observed =4666.100
# >Predicted=4666.1, Observed =4660.400
# >Predicted=4660.4, Observed =4660.400
# >Predicted=4660.4, Observed =4585.500
# >Predicted=4585.5, Observed =4597.600
# >Predicted=4597.6, Observed =4655.500
# >Predicted=4655.5, Observed =4570.900
# >Predicted=4570.9, Observed =4614.300
# >Predicted=4614.3, Observed =4611.100
# >Predicted=4611.1, Observed =4611.100
# >Predicted=4611.1, Observed =4640.600
# >Predicted=4640.6, Observed =3548.900
# >Predicted=3548.9, Observed =3605.000
# >Predicted=3605.0, Observed =4004.700
# >Predicted=4004.7, Observed =4107.200
# >Predicted=4107.2, Observed =4131.600
# >Predicted=4131.6, Observed =4156.400
# >Predicted=4156.4, Observed =4349.200
# >Predicted=4349.2, Observed =4890.500
# >Predicted=4890.5, Observed =4585.200
# >Predicted=4585.2, Observed =4516.500
# >Predicted=4516.5, Observed =4436.800
# >Predicted=4436.8, Observed =4346.100
# >Predicted=4346.1, Observed =4579.200
# >Predicted=4579.2, Observed =4613.700
# >Predicted=4613.7, Observed =4616.200
# >Predicted=4616.2, Observed =4626.100
# >Predicted=4626.1, Observed =4592.200
# >Predicted=4592.2, Observed =4609.000
# >Predicted=4609.0, Observed =4608.700
# >Predicted=4608.7, Observed =4608.700
# >Predicted=4608.7, Observed =4512.700
# >Predicted=4512.7, Observed =4485.300
# >Predicted=4485.3, Observed =4410.500
# >Predicted=4410.5, Observed =4421.200
# >Predicted=4421.2, Observed =4402.900
# >Predicted=4402.9, Observed =4403.100
# >Predicted=4403.1, Observed =4403.100
# >Predicted=4403.1, Observed =4457.600
# >Predicted=4457.6, Observed =4490.500
# >Predicted=4490.5, Observed =4458.700
# >Predicted=4458.7, Observed =3550.700
# >Predicted=3550.7, Observed =3603.100
# >Predicted=3603.1, Observed =3890.100
# >Predicted=3890.1, Observed =4118.100
# >Predicted=4118.1, Observed =4133.300
# >Predicted=4133.3, Observed =4221.500
# >Predicted=4221.5, Observed =4341.100
# >Predicted=4341.1, Observed =4869.100
# >Predicted=4869.1, Observed =4586.400
# >Predicted=4586.4, Observed =4519.300
# >Predicted=4519.3, Observed =4473.600
# >Predicted=4473.6, Observed =4343.300
# >Predicted=4343.3, Observed =4460.700
# >Predicted=4460.7, Observed =4473.400
# >Predicted=4473.4, Observed =4493.300
# >Predicted=4493.3, Observed =4478.600
# >Predicted=4478.6, Observed =4476.700
# >Predicted=4476.7, Observed =4476.700
# >Predicted=4476.7, Observed =4481.000
# >Predicted=4481.0, Observed =4503.800
# >Predicted=4503.8, Observed =4550.400
# >Predicted=4550.4, Observed =4505.000
# >Predicted=4505.0, Observed =4509.900
# >Predicted=4509.9, Observed =4509.900
# >Predicted=4509.9, Observed =4509.900
# >Predicted=4509.9, Observed =4517.400
# >Predicted=4517.4, Observed =4521.000
# >Predicted=4521.0, Observed =4470.400
# >Predicted=4470.4, Observed =4466.500
# >Predicted=4466.5, Observed =4494.400
# >Predicted=4494.4, Observed =4499.600
# >Predicted=4499.6, Observed =3559.600
# >Predicted=3559.6, Observed =3590.700
# >Predicted=3590.7, Observed =3894.900
# >Predicted=3894.9, Observed =4119.000
# >Predicted=4119.0, Observed =4137.800
# >Predicted=4137.8, Observed =4224.500
# >Predicted=4224.5, Observed =4341.700
# >Predicted=4341.7, Observed =4594.800
# >Predicted=4594.8, Observed =4579.200
# >Predicted=4579.2, Observed =4519.300
# >Predicted=4519.3, Observed =4457.200
# >Predicted=4457.2, Observed =4350.100
# >Predicted=4350.1, Observed =4514.300
# >Predicted=4514.3, Observed =4516.700
# >Predicted=4516.7, Observed =4516.700
# >Predicted=4516.7, Observed =4505.200
# >Predicted=4505.2, Observed =4507.500
# >Predicted=4507.5, Observed =4457.800
# >Predicted=4457.8, Observed =4435.300
# >Predicted=4435.3, Observed =4458.000
# >Predicted=4458.0, Observed =4454.500
# >Predicted=4454.5, Observed =4454.500
# >Predicted=4454.5, Observed =4382.700
# >Predicted=4382.7, Observed =4284.400
# >Predicted=4284.4, Observed =4282.700
# >Predicted=4282.7, Observed =4286.900
# >Predicted=4286.9, Observed =4241.100
# >Predicted=4241.1, Observed =4242.400
# >Predicted=4242.4, Observed =4242.400
# >Predicted=4242.4, Observed =4230.600
# >Predicted=4230.6, Observed =3559.600
# >Predicted=3559.6, Observed =3582.100
# >Predicted=3582.1, Observed =3745.900
# >Predicted=3745.9, Observed =4119.000
# >Predicted=4119.0, Observed =4113.100
# >Predicted=4113.1, Observed =4222.500
# >Predicted=4222.5, Observed =4341.700
# >Predicted=4341.7, Observed =4593.800
# >Predicted=4593.8, Observed =4579.200
# >Predicted=4579.2, Observed =4526.100
# >Predicted=4526.1, Observed =4496.900
# >Predicted=4496.9, Observed =4355.100
# >Predicted=4355.1, Observed =4355.100
# >Predicted=4355.1, Observed =4313.600
# >Predicted=4313.6, Observed =4368.200
# >Predicted=4368.2, Observed =4406.200
# >Predicted=4406.2, Observed =4447.900
# >Predicted=4447.9, Observed =4437.800
# >Predicted=4437.8, Observed =4443.100
# >Predicted=4443.1, Observed =4443.100
# >Predicted=4443.1, Observed =4454.200
# >Predicted=4454.2, Observed =4423.100
# >Predicted=4423.1, Observed =4434.400
# >Predicted=4434.4, Observed =4439.300
# >Predicted=4439.3, Observed =4437.900
# >Predicted=4437.9, Observed =4437.900
# >Predicted=4437.9, Observed =4455.500
# >Predicted=4455.5, Observed =4424.600
# >Predicted=4424.6, Observed =4427.600
# >Predicted=4427.6, Observed =4441.900
# >Predicted=4441.9, Observed =4440.400
# >Predicted=4440.4, Observed =4443.100
# >Predicted=4443.1, Observed =4365.300
# >Predicted=4365.3, Observed =4050.300
# >Predicted=4050.3, Observed =4065.800
# >Predicted=4065.8, Observed =4207.600
# >Predicted=4207.6, Observed =4441.900
# >Predicted=4441.9, Observed =4250.000
# >Predicted=4250.0, Observed =4331.100
# >Predicted=4331.1, Observed =4249.700
# >Predicted=4249.7, Observed =4186.700
# >Predicted=4186.7, Observed =4308.200
# >Predicted=4308.2, Observed =4285.900
# >Predicted=4285.9, Observed =4351.800
# >Predicted=4351.8, Observed =4329.900
# >Predicted=4329.9, Observed =4293.700
# >Predicted=4293.7, Observed =4289.100
# >Predicted=4289.1, Observed =4291.000
# >Predicted=4291.0, Observed =4317.400
# >Predicted=4317.4, Observed =4321.600
# >Predicted=4321.6, Observed =4374.200
# >Predicted=4374.2, Observed =4378.500
# >Predicted=4378.5, Observed =4349.400
# >Predicted=4349.4, Observed =4345.300
# >Predicted=4345.3, Observed =4345.300
# >Predicted=4345.3, Observed =4345.800
# >Predicted=4345.8, Observed =4334.200
# >Predicted=4334.2, Observed =4315.400
# >Predicted=4315.4, Observed =4311.300
# >Predicted=4311.3, Observed =4329.200
# >Predicted=4329.2, Observed =4326.400
# >Predicted=4326.4, Observed =4326.400
# >Predicted=4326.4, Observed =4443.000
# >Predicted=4443.0, Observed =4298.200
# >Predicted=4298.2, Observed =4081.400
# >Predicted=4081.4, Observed =4089.100
# >Predicted=4089.1, Observed =4207.600
# >Predicted=4207.6, Observed =4469.700
# >Predicted=4469.7, Observed =4275.500
# >Predicted=4275.5, Observed =4327.700
# >Predicted=4327.7, Observed =4243.400
# >Predicted=4243.4, Observed =4190.700
# >Predicted=4190.7, Observed =4282.600
# >Predicted=4282.6, Observed =4255.900
# >Predicted=4255.9, Observed =4251.600
# >Predicted=4251.6, Observed =4251.600
# >Predicted=4251.6, Observed =4240.600
# >Predicted=4240.6, Observed =4200.300
# >Predicted=4200.3, Observed =4141.900
# >Predicted=4141.9, Observed =4135.300
# >Predicted=4135.3, Observed =4146.000
# >Predicted=4146.0, Observed =4155.200
# >Predicted=4155.2, Observed =4155.400
# >Predicted=4155.4, Observed =4202.500
# >Predicted=4202.5, Observed =4193.600
# >Predicted=4193.6, Observed =4176.300
# >Predicted=4176.3, Observed =4147.900
# >Predicted=4147.9, Observed =4089.100
# >Predicted=4089.1, Observed =4097.900
# >Predicted=4097.9, Observed =4097.900
# >Predicted=4097.9, Observed =4443.000
# >Predicted=4443.0, Observed =4284.000
# >Predicted=4284.0, Observed =4023.200
# >Predicted=4023.2, Observed =4089.000
# >Predicted=4089.0, Observed =4246.100
# >Predicted=4246.1, Observed =4387.300
# >Predicted=4387.3, Observed =4273.700
# >Predicted=4273.7, Observed =4313.900
# >Predicted=4313.9, Observed =4284.200
# >Predicted=4284.2, Observed =4190.700
# >Predicted=4190.7, Observed =4234.600
# >Predicted=4234.6, Observed =4310.600
# >Predicted=4310.6, Observed =4029.900
# >Predicted=4029.9, Observed =4030.000
# >Predicted=4030.0, Observed =4029.100
# >Predicted=4029.1, Observed =4030.500
# >Predicted=4030.5, Observed =4050.300
# >Predicted=4050.3, Observed =4049.600
# >Predicted=4049.6, Observed =4051.800
# >Predicted=4051.8, Observed =4058.600
# >Predicted=4058.6, Observed =4058.600
# >Predicted=4058.6, Observed =4039.100
# >Predicted=4039.1, Observed =4026.900
# >Predicted=4026.9, Observed =4043.500
# >Predicted=4043.5, Observed =4025.000
# >Predicted=4025.0, Observed =4030.700
# >Predicted=4030.7, Observed =4028.900
# >Predicted=4028.9, Observed =4028.900
# >Predicted=4028.9, Observed =3996.000
# >Predicted=3996.0, Observed =3965.300
# >Predicted=3965.3, Observed =4013.200
# >Predicted=4013.2, Observed =4554.100
# >Predicted=4554.1, Observed =4204.200
# >Predicted=4204.2, Observed =3989.600
# >Predicted=3989.6, Observed =4089.000
# >Predicted=4089.0, Observed =4212.600
# >Predicted=4212.6, Observed =4426.900
# >Predicted=4426.9, Observed =4273.700
# >Predicted=4273.7, Observed =4315.700
# >Predicted=4315.7, Observed =4282.800
# >Predicted=4282.8, Observed =4231.200
# >Predicted=4231.2, Observed =4291.600
# >Predicted=4291.6, Observed =4306.800
# >Predicted=4306.8, Observed =4211.900
# >Predicted=4211.9, Observed =4183.500
# >Predicted=4183.5, Observed =4233.500
# >Predicted=4233.5, Observed =4250.200
# >Predicted=4250.2, Observed =4249.900
# >Predicted=4249.9, Observed =4249.200
# >Predicted=4249.2, Observed =4257.600
# >Predicted=4257.6, Observed =4304.000
# >Predicted=4304.0, Observed =4338.200
# >Predicted=4338.2, Observed =4302.600
# >Predicted=4302.6, Observed =4269.600
# >Predicted=4269.6, Observed =4271.100
# >Predicted=4271.1, Observed =4271.100
# >Predicted=4271.1, Observed =4274.800
# >Predicted=4274.8, Observed =4252.900
# >Predicted=4252.9, Observed =4252.500
# >Predicted=4252.5, Observed =4221.700
# >Predicted=4221.7, Observed =4205.700
# >Predicted=4205.7, Observed =4580.300
# >Predicted=4580.3, Observed =4231.800
# >Predicted=4231.8, Observed =3989.700
# >Predicted=3989.7, Observed =4063.800
# >Predicted=4063.8, Observed =4230.400
# >Predicted=4230.4, Observed =4426.400
# >Predicted=4426.4, Observed =4273.800
# >Predicted=4273.8, Observed =4304.800
# >Predicted=4304.8, Observed =4282.800
# >Predicted=4282.8, Observed =4213.000
# >Predicted=4213.0, Observed =4327.900
# >Predicted=4327.9, Observed =4306.800
# >Predicted=4306.8, Observed =4308.500
# >Predicted=4308.5, Observed =4333.100
# >Predicted=4333.1, Observed =4336.700
# >Predicted=4336.7, Observed =4336.700
# >Predicted=4336.7, Observed =4387.900
# RMSE: 183.180

# %% [markdown]
# ARIMA Hyperparameters

# %%
# grid search ARIMA parameters for a time series
import warnings
from pandas import read_csv
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, arima_order):
# prepare training dataset
    X = X.astype('float32')
    train_size = int(len(X) * 0.90)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
# make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
# model_fit = model.fit(disp=0)
        model_fit = model.fit(disp=0)
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
# calculate out of sample error
    rmse = sqrt(mean_squared_error(test, predictions))
    return rmse

# %% [markdown]
# Grid search for p,d,q values
#
# # DO NOT RUN 2nd CELL (LOAD DATASET)

# %%
# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float('inf'), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = evaluate_arima_model(train, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                    print('ARIMA%s RMSE=%.3f' % (order,rmse))
                except Exception as e :
                    print(e)
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# %%
''''# load dataset
train = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)
# evaluate parameters
p_values = range(0,5)
d_values = range(0,5)
q_values = range(0,5)
warnings.filterwarnings("ignore")
evaluate_models(train.values, p_values, d_values, q_values)'''
# Out:
# '\'# load dataset\ntrain = read_csv(\'dataset.csv\', header=None, index_col=0, parse_dates=True, squeeze=True)\n# evaluate parameters\np_values = range(0,5)\nd_values = range(0,5)\nq_values = range(0,5)\nwarnings.filterwarnings("ignore")\nevaluate_models(train.values, p_values, d_values, q_values)'

# %% [markdown]
# Build Model based on the optimized values

# %%
# save finalized model to file
from pandas import read_csv
from statsmodels.tsa.arima_model import ARIMA
import numpy
import warnings
warnings.filterwarnings('ignore')

# %%
# load data
train = read_csv('dataset.csv', index_col=0, parse_dates=True)
# prepare data
X = train.values
X = X.astype('float32')

# %%
train
# Out:
#              2252.6
# 2016-01-01
# 2016-01-02  2454.50
# 2016-01-03  2708.10
# 2016-01-04  2577.80
# 2016-01-05  2597.75
# 2016-01-06  2617.70
# ...             ...
# 2021-05-13  4308.50
# 2021-05-14  4333.10
# 2021-05-15  4336.70
# 2021-05-16  4336.70
# 2021-05-17  4387.90
#
# [1963 rows x 1 columns]

# %%
# fit model
model = ARIMA(X, order=(2,0,3))
model_fit = model.fit()
forecast=model_fit.forecast(steps=218)[0]
model_fit.plot_predict(2, 2182)
plt.show()

# %%
#Error on the test data
val=pd.read_csv('validation.csv',header=None)
rmse = sqrt(mean_squared_error(val[1], forecast))
rmse
# Out:
# 98.9122341519849

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE = mean_absolute_percentage_error(val[1], forecast)
MAPE
# Out:
# 0.018227973472960898

# %% [markdown]
# EVALUATION METRICS TO MEASURE THE PERFORMANCE:
#
# provide a summary of the forecast model’s skill and capability in making the forecasts
#
# 1) R-Squared: A high R2 indicates that the observed and anticipated values have a strong association.
#
# 2) Mean Absolute Error: - defined as the average of the absolute difference between forecasted and true values. - The lower the MAE value, the better the model; a value of zero indicates that the forecast is error-free.
#
# 3) Mean Absolute Percentage Error: - the proportion of the average absolute difference between projected and true values divided by the true value - The model is better if the MAPE is low. Remember that MAPE works best with data that is devoid of zeros and extreme values.
#
# 4) Mean Squared Error: - defined as the average of the error squares. - The closer MSE is to zero, the better.
#
# 5) Root Mean Squared Error: - defined as the square root of mean square error and is an extension of MSE. - This statistic is likewise always positive, with lower values indicating higher performance.
#
# 6) Normalized Root Mean Squared Error: - The smaller the value, the better the model’s performance.
#
# 7) Weighted Absolute Percentage Error: - It is a MAPE version in which errors are weighted by real values - The higher the model’s performance, the lower the WMAPE number. - When evaluating forecasting models, this metric is useful for low volume data where each observation has a varied priority.
#
# 8) Weighted Mean Absolute Percentage Error
#
# SUMMARY:
#
# - When the relation between the forecasted and actual value is to be known then R2 is used
#
# - MAPE is simple to understand and is used to compare different forecast models or datasets because it is a percentage value.
#
# - RMSE is easier to interpret because the RMSE number is on the same scale as the projected values.

# %%
# import pandas as pd
import pandas as pd
  
# list of strings
lst = ['ARIMA', 'SES', 'Holt method', 'Holts winter with additive seasonality & trend', 
            'Holts winter with seasonality(MUL) & trend(ADD)']
  
# list of int
lst2 = [99,244,15120,584,698] ##### RMSE

lst3 = [0,4,114,12,15] ############# MAPE
  
# Calling DataFrame constructor after zipping
# both lists, with columns specified
df = pd.DataFrame(list(zip(lst, lst2, lst3)),
               columns =['Model Name', 'RMSE', 'MAPE'])
df
# Out:
#                                         Model Name   RMSE  MAPE
# 0                                            ARIMA     99     0
# 1                                              SES    244     4
# 2                                      Holt method  15120   114
# 3   Holts winter with additive seasonality & trend    584    12
# 4  Holts winter with seasonality(MUL) & trend(ADD)    698    15

# %%
val
# Out:
#               0       1
# 0    2021-05-18  4386.1
# 1    2021-05-19  4397.9
# 2    2021-05-20  4400.6
# 3    2021-05-21  4399.4
# 4    2021-05-22  4401.8
# ..          ...     ...
# 213  2021-12-17  4394.4
# 214  2021-12-18  4389.5
# 215  2021-12-19  4389.5
# 216  2021-12-20  4354.1
# 217  2021-12-21  4346.5
#
# [218 rows x 2 columns]

# %% [markdown]
# Combine train and test data and build final model

# %%
# fit model
data = read_csv("C:\\Users\\Lenovo\\Downloads\\Gold_data.csv", header=0, index_col=0, parse_dates=True)
# prepare data
X = data.values
X = X.astype('float32')

# %%
model_arima = ARIMA(X, order=(2, 0, 3)).fit()

# %%
forecast=model_arima.forecast(steps=218)[0]
model_arima.plot_predict(2,2183)
plt.show()

# %%
final_forecast=model_arima.forecast(steps=30)[0]
final_forecast
# Out:
# array([4341.62895685, 4335.99851043, 4332.08447827, 4329.17728421,
#        4327.0178741 , 4325.41384707, 4324.22230597, 4323.33712034,
#        4322.67946653, 4322.1908018 , 4321.82764615, 4321.55770676,
#        4321.35699957, 4321.2077115 , 4321.09661268, 4321.01387722,
#        4320.95220738, 4320.90618308, 4320.87177881, 4320.84600479,
#        4320.82664051, 4320.81203678, 4320.80096873, 4320.79252665,
#        4320.78603489, 4320.78099165, 4320.77702422, 4320.77385582,
#        4320.77128084, 4320.76914662])

# %%
pred =  pd.DataFrame(final_forecast)
pred
# Out:
#               0
# 0   4341.628957
# 1   4335.998510
# 2   4332.084478
# 3   4329.177284
# 4   4327.017874
# 5   4325.413847
# 6   4324.222306
# 7   4323.337120
# 8   4322.679467
# 9   4322.190802
# 10  4321.827646
# 11  4321.557707
# 12  4321.357000
# 13  4321.207711
# 14  4321.096613
# 15  4321.013877
# 16  4320.952207
# 17  4320.906183
# 18  4320.871779
# 19  4320.846005
# 20  4320.826641
# 21  4320.812037
# 22  4320.800969
# 23  4320.792527
# 24  4320.786035
# 25  4320.780992
# 26  4320.777024
# 27  4320.773856
# 28  4320.771281
# 29  4320.769147

# %%
index_future_dates=pd.date_range(start='2021-12-22',end='2022-01-20')

# %%
pred.index=index_future_dates.rename("date")

# %%
pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30 entries, 2021-12-22 to 2022-01-20
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       30 non-null     float64
# dtypes: float64(1)
# memory usage: 480.0 bytes

# %%
pred.columns=['Price']
pred
# Out:
#                   Price
# date
# 2021-12-22  4341.628957
# 2021-12-23  4335.998510
# 2021-12-24  4332.084478
# 2021-12-25  4329.177284
# 2021-12-26  4327.017874
# 2021-12-27  4325.413847
# 2021-12-28  4324.222306
# 2021-12-29  4323.337120
# 2021-12-30  4322.679467
# 2021-12-31  4322.190802
# 2022-01-01  4321.827646
# 2022-01-02  4321.557707
# 2022-01-03  4321.357000
# 2022-01-04  4321.207711
# 2022-01-05  4321.096613
# 2022-01-06  4321.013877
# 2022-01-07  4320.952207
# 2022-01-08  4320.906183
# 2022-01-09  4320.871779
# 2022-01-10  4320.846005
# 2022-01-11  4320.826641
# 2022-01-12  4320.812037
# 2022-01-13  4320.800969
# 2022-01-14  4320.792527
# 2022-01-15  4320.786035
# 2022-01-16  4320.780992
# 2022-01-17  4320.777024
# 2022-01-18  4320.773856
# 2022-01-19  4320.771281
# 2022-01-20  4320.769147

# %%
import pandas as pd
from statsmodels.tsa.arima_model import ARIMA
from pickle import dump
from pickle import load

# %%
data = read_csv("C:\\Users\\Lenovo\\Downloads\\Gold_data.csv", header=0, index_col=0, parse_dates=True)
# prepare data
X = data.values
X = X.astype('float32')

# %%
model_arima = ARIMA(X, order=(2, 0, 3)).fit()

# %%
final_forecast=model_arima.forecast(steps=30)[0]
final_forecast
# Out:
# array([4341.62895685, 4335.99851043, 4332.08447827, 4329.17728421,
#        4327.0178741 , 4325.41384707, 4324.22230597, 4323.33712034,
#        4322.67946653, 4322.1908018 , 4321.82764615, 4321.55770676,
#        4321.35699957, 4321.2077115 , 4321.09661268, 4321.01387722,
#        4320.95220738, 4320.90618308, 4320.87177881, 4320.84600479,
#        4320.82664051, 4320.81203678, 4320.80096873, 4320.79252665,
#        4320.78603489, 4320.78099165, 4320.77702422, 4320.77385582,
#        4320.77128084, 4320.76914662])

# %%
pred =  pd.DataFrame(final_forecast)
pred
# Out:
#               0
# 0   4341.628957
# 1   4335.998510
# 2   4332.084478
# 3   4329.177284
# 4   4327.017874
# 5   4325.413847
# 6   4324.222306
# 7   4323.337120
# 8   4322.679467
# 9   4322.190802
# 10  4321.827646
# 11  4321.557707
# 12  4321.357000
# 13  4321.207711
# 14  4321.096613
# 15  4321.013877
# 16  4320.952207
# 17  4320.906183
# 18  4320.871779
# 19  4320.846005
# 20  4320.826641
# 21  4320.812037
# 22  4320.800969
# 23  4320.792527
# 24  4320.786035
# 25  4320.780992
# 26  4320.777024
# 27  4320.773856
# 28  4320.771281
# 29  4320.769147

# %%
index_future_dates=pd.date_range(start='2021-12-22',end='2022-01-20')

# %%
pred.index=index_future_dates.rename("date")

# %%
pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30 entries, 2021-12-22 to 2022-01-20
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       30 non-null     float64
# dtypes: float64(1)
# memory usage: 480.0 bytes

# %%
pred.columns=['Price']
pred
# Out:
#                   Price
# date
# 2021-12-22  4341.628957
# 2021-12-23  4335.998510
# 2021-12-24  4332.084478
# 2021-12-25  4329.177284
# 2021-12-26  4327.017874
# 2021-12-27  4325.413847
# 2021-12-28  4324.222306
# 2021-12-29  4323.337120
# 2021-12-30  4322.679467
# 2021-12-31  4322.190802
# 2022-01-01  4321.827646
# 2022-01-02  4321.557707
# 2022-01-03  4321.357000
# 2022-01-04  4321.207711
# 2022-01-05  4321.096613
# 2022-01-06  4321.013877
# 2022-01-07  4320.952207
# 2022-01-08  4320.906183
# 2022-01-09  4320.871779
# 2022-01-10  4320.846005
# 2022-01-11  4320.826641
# 2022-01-12  4320.812037
# 2022-01-13  4320.800969
# 2022-01-14  4320.792527
# 2022-01-15  4320.786035
# 2022-01-16  4320.780992
# 2022-01-17  4320.777024
# 2022-01-18  4320.773856
# 2022-01-19  4320.771281
# 2022-01-20  4320.769147

# %%
# save the model to disk
dump(model_arima, open('gold_prediction_ARIMA_model.sav', 'wb'))

# load the model from disk
loaded_model = load(open('gold_prediction_ARIMA_model.sav', 'rb'))
result = pd.DataFrame(loaded_model.forecast(steps=30)[0])
print(result)
# Out:
#               0
# 0   4341.628957
# 1   4335.998510
# 2   4332.084478
# 3   4329.177284
# 4   4327.017874
# 5   4325.413847
# 6   4324.222306
# 7   4323.337120
# 8   4322.679467
# 9   4322.190802
# 10  4321.827646
# 11  4321.557707
# 12  4321.357000
# 13  4321.207711
# 14  4321.096613
# 15  4321.013877
# 16  4320.952207
# 17  4320.906183
# 18  4320.871779
# 19  4320.846005
# 20  4320.826641
# 21  4320.812037
# 22  4320.800969
# 23  4320.792527
# 24  4320.786035
# 25  4320.780992
# 26  4320.777024
# 27  4320.773856
# 28  4320.771281
# 29  4320.769147
